# %% [markdown]
# ## Load the images

# %%
import os

input_dir = "../images"
target_dir = "../images"
DIM = 256
img_size = (DIM, DIM)
num_classes = 2
batch_size = 4

input_img_paths = sorted(
    [
        os.path.join(input_dir, fname)
        for fname in os.listdir(input_dir)
        if fname.endswith(".jpg")
    ]
)
target_img_paths = sorted(
    [
        os.path.join(target_dir, fname)
        for fname in os.listdir(target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

print("Number of samples:", len(input_img_paths))

for input_path, target_path in zip(input_img_paths[:10], target_img_paths[:10]):
    print(input_path, "|", target_path)
# Out:
# Number of samples: 20
# images\3DUS_L_probe1_conf1_ds1.dcm_p107.jpg | images\3DUS_L_probe1_conf1_ds1.dcm_p107.png
# images\3DUS_L_probe1_conf1_ds1.dcm_p124.jpg | images\3DUS_L_probe1_conf1_ds1.dcm_p124.png
# images\3DUS_L_probe1_conf1_ds1.dcm_p140.jpg | images\3DUS_L_probe1_conf1_ds1.dcm_p140.png
# images\3DUS_L_probe1_conf1_ds1.dcm_p151.jpg | images\3DUS_L_probe1_conf1_ds1.dcm_p151.png
# images\3DUS_L_probe1_conf1_ds1.dcm_p163.jpg | images\3DUS_L_probe1_conf1_ds1.dcm_p163.png
# images\3DUS_L_probe1_conf1_ds1.dcm_p183.jpg | images\3DUS_L_probe1_conf1_ds1.dcm_p183.png
# images\3DUS_L_probe1_conf1_ds1.dcm_p195.jpg | images\3DUS_L_probe1_conf1_ds1.dcm_p195.png
# images\3DUS_L_probe1_conf1_ds1.dcm_p213.jpg | images\3DUS_L_probe1_conf1_ds1.dcm_p213.png
# images\3DUS_L_probe1_conf1_ds1.dcm_p228.jpg | images\3DUS_L_probe1_conf1_ds1.dcm_p228.png
# images\3DUS_L_probe1_conf1_ds1.dcm_p240.jpg | images\3DUS_L_probe1_conf1_ds1.dcm_p240.png

# %% [markdown]
# ## Vizualise the dataset

# %%
from IPython.display import Image, display
from tensorflow.keras.preprocessing.image import load_img
from PIL import ImageOps

# Display input image #7
display(Image(filename=input_img_paths[9]))

# Get the image shape
import cv2
im = cv2.imread(input_img_paths[9])
img_size = im.shape
print(img_size)

# Display auto-contrast version of corresponding target (per-pixel categories)
img = ImageOps.autocontrast(load_img(target_img_paths[9]))
display(img)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Antony\OneDrive\HES-SO\Semestre2\PA_UltraMotion\Code\U-Net\U-Net.ipynb Cell 4 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Antony/OneDrive/HES-SO/Semestre2/PA_UltraMotion/Code/U-Net/U-Net.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from IPython.display import Image, display
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Antony/OneDrive/HES-SO/Semestre2/PA_UltraMotion/Code/U-Net/U-Net.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> from tensorflow.keras.preprocessing.image import load_img
#       <a href='vscode-notebook-cell:/c%3A/Users/Antony/OneDrive/HES-SO/Semestre2/PA_UltraMotion/Code/U-Net/U-Net.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> from PIL import ImageOps
#       <a href='vscode-notebook-cell:/c%3A/Users/Antony/OneDrive/HES-SO/Semestre2/PA_UltraMotion/Code/U-Net/U-Net.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> # Display input image #7
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\__init__.py:42
#      37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\data\__init__.py:21
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\data\experimental\__init__.py:95
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      91 @@UNKNOWN_CARDINALITY
#      92 """
#      94 # pylint: disable=unused-import
# ---> 95 from tensorflow.python.data.experimental import service
#      96 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      97 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py:387
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     384   job of ParameterServerStrategy).
#     385 """
# --> 387 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     388 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     389 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:26
#      24 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      25 from tensorflow.python.data.experimental.service import _pywrap_utils
# ---> 26 from tensorflow.python.data.ops import dataset_ops
#      27 from tensorflow.python.data.ops import options as options_lib
#      28 from tensorflow.python.data.ops import structured_function
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:31
#      29 from tensorflow.core.framework import graph_pb2
#      30 from tensorflow.python import tf2
# ---> 31 from tensorflow.python.data.ops import iterator_ops
#      32 from tensorflow.python.data.ops import options as options_lib
#      33 from tensorflow.python.data.ops import structured_function
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:36
#      34 from tensorflow.python.framework import type_spec
#      35 from tensorflow.python.ops import gen_dataset_ops
# ---> 36 from tensorflow.python.training.saver import BaseSaverBuilder
#      37 from tensorflow.python.training.tracking import base as trackable
#      38 from tensorflow.python.types import trace
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\training\saver.py:36
#      34 from tensorflow.python.framework import device as pydev
#      35 from tensorflow.python.framework import errors
# ---> 36 from tensorflow.python.framework import meta_graph
#      37 from tensorflow.python.framework import ops
#      38 from tensorflow.python.ops import array_ops
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\framework\meta_graph.py:35
#      33 from tensorflow.python.framework import error_interpolation
#      34 from tensorflow.python.framework import graph_io
# ---> 35 from tensorflow.python.framework import importer
#      36 from tensorflow.python.framework import op_def_registry
#      37 from tensorflow.python.framework import ops
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\framework\importer.py:24
#      22 from tensorflow.python.framework import device as pydev
#      23 from tensorflow.python.framework import errors
# ---> 24 from tensorflow.python.framework import function
#      25 from tensorflow.python.framework import op_def_registry
#      26 from tensorflow.python.framework import ops
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\framework\function.py:33
#      31 from tensorflow.python.framework import ops
#      32 from tensorflow.python.ops import array_ops
# ---> 33 from tensorflow.python.ops import resource_variable_ops
#      34 from tensorflow.python.ops import variable_scope as vs
#      35 from tensorflow.python.util import compat
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:47
#      45 from tensorflow.python.ops import math_ops
#      46 from tensorflow.python.ops import state_ops
# ---> 47 from tensorflow.python.ops import variables
#      48 # go/tf-wildcard-import
#      49 # pylint: disable=wildcard-import
#      50 from tensorflow.python.ops.gen_resource_variable_ops import *
#
# File c:\Users\Antony\Documents\HES-SO\Code\HES\lib\site-packages\tensorflow\python\ops\variables.py:39
#      37 from tensorflow.python.ops import state_ops
#      38 from tensorflow.python.platform import tf_logging as logging
# ---> 39 from tensorflow.python.training.tracking import base as trackable
#      40 from tensorflow.python.util import _pywrap_utils
#      41 from tensorflow.python.util import compat
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1002, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:945, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1430, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1402, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1539, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:1582, in _fill_cache(self)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Prepare Sequence class to load & vectorize batches of data

# %%
from tensorflow import keras
import numpy as np
from tensorflow.keras.preprocessing.image import load_img


class OxfordPets(keras.utils.Sequence):
    """Helper to iterate over the data (as Numpy arrays)."""

    def __init__(self, batch_size, img_size, input_img_paths, target_img_paths):
        self.batch_size = batch_size
        self.img_size = img_size
        self.input_img_paths = input_img_paths
        self.target_img_paths = target_img_paths

    def __len__(self):
        return len(self.target_img_paths) // self.batch_size

    def __getitem__(self, idx):
        """Returns tuple (input, target) correspond to batch #idx."""
        i = idx * self.batch_size
        batch_input_img_paths = self.input_img_paths[i : i + self.batch_size]
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size]
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype="float32")
        for j, path in enumerate(batch_input_img_paths):
            img = load_img(path, target_size=self.img_size)
            x[j] = img
        y = np.zeros((self.batch_size,) + self.img_size + (1,), dtype="uint8")
        for j, path in enumerate(batch_target_img_paths):
            img = load_img(path, target_size=self.img_size, color_mode="grayscale")
            y[j] = np.expand_dims(img, 2)
            # Ground truth labels are 1, 2, 3. Subtract one to make them 0, 1, 2:
            y[j] -= 1
        return x, y

# %% [markdown]
# ## Prepare U-Net Xception-style model

# %%
from models.unet import get_model

# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
model = get_model(img_size, num_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 256, 256, 32  0           ['activation[0][0]']
#                                 )
#
#  separable_conv2d (SeparableCon  (None, 256, 256, 64  2400       ['activation_1[0][0]']
#  v2D)                           )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['separable_conv2d[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  separable_conv2d_1 (SeparableC  (None, 256, 256, 64  4736       ['activation_2[0][0]']
#  onv2D)                         )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 64  256        ['separable_conv2d_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 64  2112        ['activation[0][0]']
#                                 )
#
#  add (Add)                      (None, 128, 128, 64  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  activation_3 (Activation)      (None, 128, 128, 64  0           ['add[0][0]']
#                                 )
#
#  separable_conv2d_2 (SeparableC  (None, 128, 128, 12  8896       ['activation_3[0][0]']
#  onv2D)                         8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['separable_conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_4 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  separable_conv2d_3 (SeparableC  (None, 128, 128, 12  17664      ['activation_4[0][0]']
#  onv2D)                         8)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 12  512        ['separable_conv2d_3[0][0]']
#  rmalization)                   8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['batch_normalization_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  8320        ['add[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 128)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  activation_5 (Activation)      (None, 64, 64, 128)  0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 64, 64, 256)  34176      ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 256)  1024       ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 64, 64, 256)  68096      ['activation_6[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 256)  1024       ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['batch_normalization_6[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 256)  33024       ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 256)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  activation_7 (Activation)      (None, 32, 32, 256)  0           ['add_2[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  590080     ['activation_7[0][0]']
#  ose)
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_transpose[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  590080     ['activation_8[0][0]']
#  spose)
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_transpose_1[0][0]']
#  rmalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0          ['add_2[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 256)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  65792       ['up_sampling2d_1[0][0]']
#
#  add_3 (Add)                    (None, 64, 64, 256)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  activation_9 (Activation)      (None, 64, 64, 256)  0           ['add_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  295040     ['activation_9[0][0]']
#  spose)
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_transpose_2[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 128)  147584     ['activation_10[0][0]']
#  spose)
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 128)  512        ['conv2d_transpose_3[0][0]']
#  ormalization)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 25  0          ['add_3[0][0]']
#                                 6)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 12  0          ['batch_normalization_10[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  32896       ['up_sampling2d_3[0][0]']
#                                 8)
#
#  add_4 (Add)                    (None, 128, 128, 12  0           ['up_sampling2d_2[0][0]',
#                                 8)                                'conv2d_5[0][0]']
#
#  activation_11 (Activation)     (None, 128, 128, 12  0           ['add_4[0][0]']
#                                 8)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 128, 128, 64  73792      ['activation_11[0][0]']
#  spose)                         )
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 64  256        ['conv2d_transpose_4[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 64  36928      ['activation_12[0][0]']
#  spose)                         )
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 64  256        ['conv2d_transpose_5[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 12  0          ['add_4[0][0]']
#                                 8)
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 64  0          ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 64  8256        ['up_sampling2d_5[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 256, 256, 64  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'conv2d_6[0][0]']
#
#  activation_13 (Activation)     (None, 256, 256, 64  0           ['add_5[0][0]']
#                                 )
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 32  18464      ['activation_13[0][0]']
#  spose)                         )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 32  128        ['conv2d_transpose_6[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 32  9248       ['activation_14[0][0]']
#  spose)                         )
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 32  128        ['conv2d_transpose_7[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 512, 512, 64  0          ['add_5[0][0]']
#                                 )
#
#  up_sampling2d_6 (UpSampling2D)  (None, 512, 512, 32  0          ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 32  2080        ['up_sampling2d_7[0][0]']
#                                 )
#
#  add_6 (Add)                    (None, 512, 512, 32  0           ['up_sampling2d_6[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 2)  578         ['add_6[0][0]']
#
# ==================================================================================================
# Total params: 2,058,690
# Trainable params: 2,054,914
# Non-trainable params: 3,776
# __________________________________________________________________________________________________

# %% [markdown]
# ## Set aside a validation split

# %%
import random

# Split our img paths into a training and a validation set
val_samples = 4
random.Random(1337).shuffle(input_img_paths)
random.Random(1337).shuffle(target_img_paths)
train_input_img_paths = input_img_paths[:-val_samples]
train_target_img_paths = target_img_paths[:-val_samples]
val_input_img_paths = input_img_paths[-val_samples:]
val_target_img_paths = target_img_paths[-val_samples:]

# Instantiate data Sequences for each split
train_gen = OxfordPets(
    batch_size, img_size, train_input_img_paths, train_target_img_paths
)
val_gen = OxfordPets(batch_size, img_size, val_input_img_paths, val_target_img_paths)

# %% [markdown]
# ## Train the model

# %%
# Configure the model for training.
# We use the "sparse" version of categorical_crossentropy
# because our target data is integers.
model.compile(optimizer="rmsprop", loss="sparse_categorical_crossentropy")

callbacks = [
    keras.callbacks.ModelCheckpoint("oxford_segmentation.h5", save_best_only=True)
]

# Train the model, doing validation at the end of each epoch.
epochs = 15
model.fit(train_gen, epochs=epochs, validation_data=val_gen, callbacks=callbacks)
# Out:
# Epoch 1/15

# %% [markdown]
# ## Visualize predictions

# %%
# Generate predictions for all images in the validation set

val_gen = OxfordPets(batch_size, img_size, val_input_img_paths, val_target_img_paths)
val_preds = model.predict(val_gen)


def display_mask(i):
    """Quick utility to display a model's prediction."""
    mask = np.argmax(val_preds[i], axis=-1)
    mask = np.expand_dims(mask, axis=-1)
    img = ImageOps.autocontrast(keras.preprocessing.image.array_to_img(mask))
    display(img)


# Display results for validation image #10
i = 10

# Display input image
display(Image(filename=val_input_img_paths[i]))

# Display ground-truth target mask
img = ImageOps.autocontrast(load_img(val_target_img_paths[i]))
display(img)

# Display mask predicted by our model
display_mask(i)  # Note that the model only sees inputs at 150x150.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Antony\OneDrive\HES-SO\Semestre2\PA_UltraMotion\Code\U-Net\U-Net.ipynb Cell 14 in 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Antony/OneDrive/HES-SO/Semestre2/PA_UltraMotion/Code/U-Net/U-Net.ipynb#X16sZmlsZQ%3D%3D?line=15'>16</a> i = 10
#      <a href='vscode-notebook-cell:/c%3A/Users/Antony/OneDrive/HES-SO/Semestre2/PA_UltraMotion/Code/U-Net/U-Net.ipynb#X16sZmlsZQ%3D%3D?line=17'>18</a> # Display input image
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Antony/OneDrive/HES-SO/Semestre2/PA_UltraMotion/Code/U-Net/U-Net.ipynb#X16sZmlsZQ%3D%3D?line=18'>19</a> display(Image(filename=val_input_img_paths[i]))
#      <a href='vscode-notebook-cell:/c%3A/Users/Antony/OneDrive/HES-SO/Semestre2/PA_UltraMotion/Code/U-Net/U-Net.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a> # Display ground-truth target mask
#      <a href='vscode-notebook-cell:/c%3A/Users/Antony/OneDrive/HES-SO/Semestre2/PA_UltraMotion/Code/U-Net/U-Net.ipynb#X16sZmlsZQ%3D%3D?line=21'>22</a> img = ImageOps.autocontrast(load_img(val_target_img_paths[i]))
#
# IndexError: list index out of range
